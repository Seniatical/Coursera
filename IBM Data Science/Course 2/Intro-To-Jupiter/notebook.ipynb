# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Project

# %% [markdown]
# ## Introduction
#
# This is my final project introduction, enjoy.

# %% [markdown]
# ## Data Science Languages
# * Python
# * R
# * SQL

# %% [markdown]
# ## Data Science Libraries
#
# * Numpy
# * Pandas
# * Natural Language Toolkit (NLTK)
# * Dplyr
# * Ggplot

# %% [markdown]
# ## Data Science Tools
#
# | Tool    | Description |
# | -------- | ------- |
# | SQL  | A Query Language Which is Used for Storing and Accessing Data |
# | Jupyter Notebook | $80     |

# %% [markdown]
# ## Introduction to Basic Arithmetic
# View example of basic arithmetic below

# %%
# Basic Arithmetic, adding and multiplying numbers
(30 + 5) * 5
# Out:
# 175

# %%
# Converting Minutes into Hours
def hours_to_mins(minutes: int) -> float:
    return minutes / 60

hours_to_mins(120)
# Out:
# 2.0

# %% [markdown]
# ## Objectives
# View the objectives set below
# * Objective 1
# * Objective 2
# * Objective 3
# * Objective 4
# * Objective 5

# %% [markdown]
# ### Author - Isa
